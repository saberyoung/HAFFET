# %% [markdown]
# # play with full Ibc sample

# %%
import sys
sys.path.append('../src')
from ztfanalysis import *
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
ztfp = ztfmultiple(datafile='tmp/%s_data.clf',
                   parfile='priors.txt',
                   datadir='/Users/yash0613/Library/CloudStorage/Box-Box/ztf_data/')
ztfp.parse_meta()
ztfp.format_meta()  
ztfp.parse_params()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
ztfp.parse_params(force=True)
if False:
    ztfp.run(nsn=0, verbose=True, clobber=False, axes=None)
elif True:
    ztfp.run(ztfid='ZTF21abmlldj', verbose=True, clobber=False, axes=None)
else:
    ztfp.run(verbose=True, clobber=False, axes=False)
# Out:
#  0 ZTF21abmlldj SN2021uvy SN Ib

# %%
for nsn in range(142):
    ztfid = ztfp.meta.index[nsn]
    ztfp.data[ztfid].show()

# %%
ztfplot = plotter(ztfp)
ztfplot.init_fig()
#ztfplot.show2d(k1='z',k2='dm',ls='',marker='o',fillstyle='none',color='k')
#ztfplot.add_hist(nbiny=10)
#ztfplot.showlc(ls='',fillstyle='none',marker='o')
#ztfplot.showcolor(ls='',fillstyle='none',marker='o')
#ztfplot.showfit(filt='g',ls='-',)
#ztfplot.ax.invert_yaxis()
#ztfplot.showlcbol(ls='',fillstyle='none',marker='o')
#ztfplot.showarnett()
#ztfplot.ax.set_yscale('log')
#ztfplot.ax.set_ylim([1e40,5e43])
#ztfplot.ax.set_xlim([-60,40])

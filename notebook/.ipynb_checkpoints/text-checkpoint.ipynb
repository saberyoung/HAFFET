# %%
from sdapy.ztfanalysis import *
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # use ztfsingle to do fits step by step

# %% [markdown]
# ### redshift, distance module and milky way ebv is needed

# %%
ztfid = 'ZTF19abtsnyy'
ztfm = ztfmultiple(datadir='/Users/yash0613/Library/CloudStorage/Box-Box/ztf_data/',
                   metafile='rcf_query.txt', verbose=True)
ztfm.parse_meta()
ztfm.format_meta()
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# meta 142 objs

# %% [markdown]
# ### show flux and mag plots

# %%
# initialize class
ztfm.parse_params(force=True)
par = dict()
if ztfid in ztfm.params: par = ztfm.params[ztfid]

ztfp = ztfsingle(ztfid=ztfid, iauid=ztfm.meta['IAUID'][ztfid], 
                 z=ztfm.meta['redshift'][ztfid],
                 dm=ztfm.meta['dm'][ztfid],
                 mkwebv=ztfm.meta['ebv'][ztfid],
                 sntype=ztfm.meta['type'][ztfid], **par)
ztfp.run()
# Out:
# Prepare data in = 0.75 s
# Run GP in = 2.98 s
# Run Fitting in = 0.01 s
# Run early power law fit in = 0.66 s
# calc colour in = 0.95 s
# est host ebv in = 0.00 s
# calc lyman bol in = 0.01 s
# fit arnett model in = 0.00 s
# fit tail model in = 0.00 s
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-858608c5a92f> in <module>
#       9                  mkwebv=ztfm.meta['ebv'][ztfid],
#      10                  sntype=ztfm.meta['type'][ztfid], **par)
# ---> 11 ztfp.run()
#
# /opt/miniconda3/envs/ampelexports/lib/python3.6/site-packages/sn_data_analysis-0.0.0.1-py3.6.egg/sdapy/ztfanalysis.py in run(self, **kwargs)
#     916
#     917         ''' go to spectral part '''
# --> 918         self.get_local_spectra()  # obtain local spectra
#     919         if kwargs['verbose']:
#     920             print("get local spectra in = {:.2f} s".format(time.time() - t_start))
#
# /opt/miniconda3/envs/ampelexports/lib/python3.6/site-packages/sn_data_analysis-0.0.0.1-py3.6.egg/sdapy/ztfanalysis.py in get_local_spectra(self, **kwargs)
#     817                 except:  print ( os.path.join(dir_,d) )
#     818         # spec from fritz
# --> 819         _spec = fritz.FritzSpectrum.from_name( self.ztfid )
#     820         if _spec is not None:
#     821             if type(_spec) is list:
#
# /opt/miniconda3/envs/ampelexports/lib/python3.6/site-packages/ztfquery-1.18.0-py3.6.egg/ztfquery/fritz.py in from_name(cls, name, warn, force_dl, store, **kwargs)
#    1078
#    1079         # No Local spectra or force download.
# -> 1080         spectra = download_spectra(name, get_object=False, store=store)
#    1081         if spectra is None or len(spectra) == 0:
#    1082             if warn:
#
# /opt/miniconda3/envs/ampelexports/lib/python3.6/site-packages/ztfquery-1.18.0-py3.6.egg/ztfquery/fritz.py in download_spectra(name, get_object, token, store, verbose)
#     221         print(f"queried URL: {q_url}")
#     222
# --> 223     list_of_dict = api('get', q_url, load=True, token=token)
#     224     #
#     225     # - Any problem ?
#
# /opt/miniconda3/envs/ampelexports/lib/python3.6/site-packages/ztfquery-1.18.0-py3.6.egg/ztfquery/fritz.py in api(method, endpoint, data, load, token, **kwargs)
#      48
#      49     if downloaded["status"] not in ["success"]:
# ---> 50         raise IOError(f"downloading status of '{method} {endpoint}' is not success: {downloaded['status']}")
#      51
#      52     return downloaded["data"]
#
# OSError: downloading status of 'get https://fritz.science/api/sources/ZTF19abtsnyy/spectra' is not success: error

# %%
# initialize class
ztfm.parse_params(force=True)
par = dict()
if ztfid in ztfm.params: par = ztfm.params[ztfid]

ztfp = ztfsingle(ztfid=ztfid, iauid=ztfm.meta['IAUID'][ztfid], 
                 z=ztfm.meta['redshift'][ztfid],
                 dm=ztfm.meta['dm'][ztfid],
                 mkwebv=ztfm.meta['ebv'][ztfid],
                 sntype=ztfm.meta['type'][ztfid], **par)

# get forced lightcurves
sigma = 5
df = pd.read_csv('/Users/yash0613/Desktop/%s_fnu.csv'%ztfid,sep=',')
df.rename(columns={'jd':'jdobs',
                   'fnu_microJy':'Fpsf',
                   'fnu_microJy_unc':'Fpsf_unc',
                   'zpdiff':'zp',
                   'sys_unc_factor': 'ezp',
                   'passband': 'filter'}, inplace=True)
        
mags, sigmamags, limmags, filters, frat, efrat = [], [], [], [], [], []
for _ in df.index:
    flux, fluxerr, filtro, zpdiff = df['Fpsf'][_], df['Fpsf_unc'][_], \
                                    df['filter'][_], df['zp'][_]
    snr = flux / fluxerr
    zpdiff = 23.9
    F0 = 10**(zpdiff/2.5)
    Fratio = flux / F0
    eFratio = fluxerr / F0
    if flux > 0 and snr > sigma:
        magpsf = -2.5*np.log10(flux) + zpdiff
        sigmamagpsf = abs(-2.5/np.log(10) * fluxerr / flux)
    else:
        magpsf = 99
        sigmamagpsf = 99
    limmag = -2.5*np.log10(sigma*fluxerr) + zpdiff
    mags.append(magpsf)
    sigmamags.append(sigmamagpsf)
    limmags.append(limmag)
    filters.append(filtro.replace('ZTF_',''))    
    frat.append(Fratio)
    efrat.append(eFratio)
df['mag'] = mags
df['emag'] = sigmamags
df['limmag'] = limmags
df['filter'] = filters
df['Fratio'] = frat
df['Fratio_unc'] = efrat
ztfp.lc = df

ztfp.add_flux()
ztfp.init_fig()
ztfp.on_sntype() # check sn type   
ztfp.run_gp()     # Gaussian process
ztfp.set_t0_withgp()
ztfp.set_texp_midway() # try to set texp    
ztfp.run_fit()   # sn-like analytic functions
ztfp.explosion_pl()  # power law for first light
ztfp.calc_colors()  # g-r colour epochs
ztfp.est_host_c10()   # use g-r compared to tpl for host ebv
ztfp.lyman_bol()  # calculate luminosity from g,r with Lyman bol correction
ztfp.arnett_fit() # fit lums around peak to arnett model
ztfp.tail_fit()   # fit lums at tail to gamma leakage model
ztfp.get_local_spectra()  # obtain local spectra
ztfp.meas_specline()  # measure specific lines, fit photos v to break arnett degenaracy
ztfp.plot()   # plot everything
